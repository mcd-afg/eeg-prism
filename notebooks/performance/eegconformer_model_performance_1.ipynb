# %% [markdown]
# ## EEGConformer - 24 noviembre

# %%
# Load CSV, detect columns, and plot train vs validation cross-entropy over epochs
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Paths

csv_path = Path("/Users/rocioperez/Documents/Projects/AFG/Git_Group_Project/eeg-prism/data/training_history_eegconformer.csv")
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    epoch  train_loss  valid_loss  train_accuracy  valid_accuracy
# 0      1    0.868247    5.290444        0.671165        0.167788
# 1      2    0.857724    0.868065        0.672626        0.666651
# 2      3    0.852733    1.021495        0.673078        0.661958
# 3      4    0.848916    0.985435        0.673545        0.666663
# 4      5    0.847013    1.923333        0.673826        0.166023

# %%
plt.figure(figsize=(6, 4))
plt.title("EEGConformer Model Loss")
plt.plot(df['epoch'], df['train_loss'], label="train")
plt.xlabel("Epoch")
plt.ylabel("Categorical cross-entropy")
plt.legend()
plt.tight_layout()

# %%
plt.figure(figsize=(6, 4))
plt.title("EEGConformer Model Accuracy")
plt.plot(df['epoch'], df['train_accuracy'], label="train")
#plt.plot(df['epoch'], df['valid_accuracy'], label="validation")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()

# %%
plt.figure(figsize=(6, 4))
plt.title("EEGConformer Model Loss")
plt.plot(df['epoch'], df['train_loss'], label="train")
plt.plot(df['epoch'], df['valid_loss'], label="validation")
plt.xlabel("Epoch")
plt.ylabel("Categorical cross-entropy")
plt.legend()
plt.tight_layout()

# %%
plt.figure(figsize=(6, 4))
plt.title("EEGConformer Model Accuracy")
plt.plot(df['epoch'], df['train_accuracy'], label="train")
plt.plot(df['epoch'], df['valid_accuracy'], label="validation")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
