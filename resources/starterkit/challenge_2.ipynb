# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/eeg2025/startkit/blob/main/challenge_2.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge 2: Predicting the externalizing factor from EEG
#
# The externalizing factor is a widely recognized construct in mental health research, representing a common underlying dimension of psychopathology across various disorders.
# Currently, the externalizing factor is often assessed using self-report questionnaires or clinician ratings, which can be subjective, prone to bias, and time-consuming.
# **The Challenge 2** consists of developing a model to predict the externalizing factor from EEG recordings.
#
# The challenge encourages learning physiologically meaningful signal representations and discovery of reproducible biomarkers.
# Models of any size should emphasize robust, interpretable features that generalize across subjects,
# sessions, and acquisition sites.
#
# Unlike a standard in-distribution classification task, this regression problem stresses out-of-distribution robustness
# and extrapolation. The goal is not only to minimize error on seen subjects, but also to transfer effectively to unseen data.
#
# Ensure the dataset is available locally. If not, see the [dataset download guide](https://eeg2025.github.io/data/#downloading-the-data)

# %% [markdown]
# ## Contents of this start kit
#
# 0. Understand the externalizing factor regression task.
# 1. Loading the data.
# 2. Wrap the data into a PyTorch-compatible dataset.
# 3. Define, train and save a model.
#
# > **Note:** If you need additional explanations on the [`EEGChallengeDataset`](https://eeglab.org/EEGDash/api/eegdash.html#eegdash.EEGChallengeDataset) class, dataloading, [`braindecode`](https://braindecode.org/stable/models/models_table.html)'s deep learning models, or brain decoding in general, please refer to the start-kit of challenge 1 which delves deeper into these topics.
#
# More contents will be released during the competition inside the [`eegdash`](https://eeglab.org/EEGDash/overview.html) [examples webpage](https://eeglab.org/EEGDash/generated/auto_examples/index.html).
#
# We will establish direct communication channels with you over the next two months, resolve platform issues, and discuss other details.
#
# We are going to do weekly one-hour support time to help teams that may have difficulties with any technical aspects that may arise.
#
# We will have closer communication starting next week, 08/09/2025.
#
# Before we begin, I just want to make a deal with you, ok?
#
# This is a community competition with a strong open-source foundation. When I say open-source, I mean volunteer work.
#
# So, if you see something that does not work or could be improved, first, **please be kind**, and we will fix it together on GitHub, okay?
#
# The entire decoding community will only go further when we stop solving the same problems over and over again, and start working together.

# %% [markdown]
# ----
# | The tutorial assumes some prior knowledge of deep learning concepts and EEG concepts:|
# | --- |
# |* Standard neural network architectures, e.g., convolutional neural networks|
# |* Optimization by batch gradient descent and backpropagation|
# |* Overfitting, early stopping, regularisation |
# |* Some knowledge of pytorch and, optionally, of the pytorch Lightning framework|
# |* That you know what EEG is |
# |* That you have basic familiarity with EEG preprocessing |
# |* Like and support open-source :) |
# ----

# %%
# !pip install braindecode
# !pip install eegdash
# Out:
# Collecting braindecode
#   Downloading braindecode-1.2.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting mne>=1.10.0 (from braindecode)
#   Downloading mne-1.10.2-py3-none-any.whl.metadata (21 kB)
# Collecting mne_bids>=0.16 (from braindecode)
#   Downloading mne_bids-0.17.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from braindecode) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from braindecode) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from braindecode) (1.16.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from braindecode) (3.10.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from braindecode) (3.15.1)
# Collecting skorch>=1.2.0 (from braindecode)
#   Downloading skorch-1.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from braindecode) (2.8.0+cu126)
# Requirement already satisfied: torchaudio<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from braindecode) (2.8.0+cu126)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from braindecode) (0.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from braindecode) (1.5.2)
# Collecting torchinfo~=1.8 (from braindecode)
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Collecting wfdb (from braindecode)
#   Downloading wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting linear_attention_transformer (from braindecode)
#   Downloading linear_attention_transformer-0.19.1-py3-none-any.whl.metadata (787 bytes)
# Collecting docstring_inheritance (from braindecode)
#   Downloading docstring_inheritance-2.2.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode) (0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode) (25.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode) (1.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode) (2.9.0.post0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from skorch>=1.2.0->braindecode) (1.6.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.12/dist-packages (from skorch>=1.2.0->braindecode) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode) (3.4.0)
# Collecting axial-positional-embedding (from linear_attention_transformer->braindecode)
#   Downloading axial_positional_embedding-0.3.12-py3-none-any.whl.metadata (4.3 kB)
# Collecting linformer>=0.1.0 (from linear_attention_transformer->braindecode)
#   Downloading linformer-0.2.3-py3-none-any.whl.metadata (602 bytes)
# Collecting local-attention (from linear_attention_transformer->braindecode)
#   Downloading local_attention-1.11.2-py3-none-any.whl.metadata (929 bytes)
# Collecting product-key-memory>=0.1.5 (from linear_attention_transformer->braindecode)
#   Downloading product_key_memory-0.2.11-py3-none-any.whl.metadata (717 bytes)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->braindecode) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->braindecode) (2025.2)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from wfdb->braindecode) (3.13.1)
# Collecting pandas (from braindecode)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from wfdb->braindecode) (2.32.4)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb->braindecode) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb->braindecode) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb->braindecode) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb->braindecode) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb->braindecode) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.22.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne>=1.10.0->braindecode) (4.5.0)
# Collecting colt5-attention>=0.10.14 (from product-key-memory>=0.1.5->linear_attention_transformer->braindecode)
#   Downloading CoLT5_attention-0.11.1-py3-none-any.whl.metadata (737 bytes)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->braindecode) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb->braindecode) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb->braindecode) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb->braindecode) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb->braindecode) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->skorch>=1.2.0->braindecode) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.0->wfdb->braindecode) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.0->braindecode) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mne>=1.10.0->braindecode) (3.0.3)
# Collecting hyper-connections>=0.1.8 (from local-attention->linear_attention_transformer->braindecode)
#   Downloading hyper_connections-0.2.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb->braindecode) (2.23)
# Downloading braindecode-1.2.0-py3-none-any.whl (305 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 6.8 MB/s eta 0:00:00
# Downloading mne-1.10.2-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 34.7 MB/s eta 0:00:00
# Downloading mne_bids-0.17.0-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.9/168.9 kB 6.4 MB/s eta 0:00:00
# Downloading skorch-1.2.0-py3-none-any.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.1/263.1 kB 9.1 MB/s eta 0:00:00
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading docstring_inheritance-2.2.2-py3-none-any.whl (24 kB)
# Downloading linear_attention_transformer-0.19.1-py3-none-any.whl (12 kB)
# Downloading wfdb-4.3.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 5.7 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 29.3 MB/s eta 0:00:00
# Downloading linformer-0.2.3-py3-none-any.whl (6.2 kB)
# Downloading product_key_memory-0.2.11-py3-none-any.whl (6.5 kB)
# Downloading axial_positional_embedding-0.3.12-py3-none-any.whl (6.7 kB)
# Downloading local_attention-1.11.2-py3-none-any.whl (9.5 kB)
# Downloading CoLT5_attention-0.11.1-py3-none-any.whl (18 kB)
# Downloading hyper_connections-0.2.1-py3-none-any.whl (16 kB)
# Installing collected packages: torchinfo, docstring_inheritance, pandas, wfdb, skorch, mne, mne_bids, linformer, hyper-connections, axial-positional-embedding, local-attention, colt5-attention, product-key-memory, linear_attention_transformer, braindecode
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# Successfully installed axial-positional-embedding-0.3.12 braindecode-1.2.0 colt5-attention-0.11.1 docstring_inheritance-2.2.2 hyper-connections-0.2.1 linear_attention_transformer-0.19.1 linformer-0.2.3 local-attention-1.11.2 mne-1.10.2 mne_bids-0.17.0 pandas-2.3.3 product-key-memory-0.2.11 skorch-1.2.0 torchinfo-1.8.0 wfdb-4.3.0
# Collecting eegdash
#   Downloading eegdash-0.4.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: braindecode>=1.0 in /usr/local/lib/python3.12/dist-packages (from eegdash) (1.2.0)
# Requirement already satisfied: mne_bids>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from eegdash) (0.17.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from eegdash) (0.60.0)
# Collecting pymongo (from eegdash)
#   Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting s3fs (from eegdash)
#   Downloading s3fs-2025.9.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from eegdash) (4.67.1)
# Collecting pymatreader (from eegdash)
#   Downloading pymatreader-1.1.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting eeglabio (from eegdash)
#   Downloading eeglabio-0.1.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from eegdash) (0.9.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from eegdash) (13.9.4)
# Requirement already satisfied: mne>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (1.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (2.3.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (1.16.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (3.10.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (3.15.1)
# Requirement already satisfied: skorch>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (1.2.0)
# Requirement already satisfied: torch<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (2.8.0+cu126)
# Requirement already satisfied: torchaudio<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (2.8.0+cu126)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (0.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (1.5.2)
# Requirement already satisfied: torchinfo~=1.8 in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (1.8.0)
# Requirement already satisfied: wfdb in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (4.3.0)
# Requirement already satisfied: linear_attention_transformer in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (0.19.1)
# Requirement already satisfied: docstring_inheritance in /usr/local/lib/python3.12/dist-packages (from braindecode>=1.0->eegdash) (2.2.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->eegdash) (0.43.0)
# Collecting xmltodict (from pymatreader->eegdash)
#   Downloading xmltodict-1.0.2-py3-none-any.whl.metadata (15 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo->eegdash)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->eegdash) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->eegdash) (2.19.2)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs->eegdash)
#   Downloading aiobotocore-2.25.1-py3-none-any.whl.metadata (25 kB)
# Collecting fsspec==2025.9.0 (from s3fs->eegdash)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from s3fs->eegdash) (3.13.1)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting botocore<1.40.62,>=1.40.46 (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash)
#   Downloading botocore-1.40.61-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (2.9.0.post0)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (6.7.0)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash)
#   Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.22.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->eegdash) (0.1.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (25.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.12/dist-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (1.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode>=1.0->eegdash) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode>=1.0->eegdash) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode>=1.0->eegdash) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode>=1.0->eegdash) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode>=1.0->eegdash) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->braindecode>=1.0->eegdash) (3.2.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from skorch>=1.2.0->braindecode>=1.0->eegdash) (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.4.0)
# Requirement already satisfied: axial-positional-embedding in /usr/local/lib/python3.12/dist-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.3.12)
# Requirement already satisfied: linformer>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.3)
# Requirement already satisfied: local-attention in /usr/local/lib/python3.12/dist-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (1.11.2)
# Requirement already satisfied: product-key-memory>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.11)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->braindecode>=1.0->eegdash) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->braindecode>=1.0->eegdash) (2025.2)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from wfdb->braindecode>=1.0->eegdash) (2.32.4)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb->braindecode>=1.0->eegdash) (0.13.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.40.62,>=1.40.46->aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (2.5.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (4.5.0)
# Requirement already satisfied: colt5-attention>=0.10.14 in /usr/local/lib/python3.12/dist-packages (from product-key-memory>=0.1.5->linear_attention_transformer->braindecode>=1.0->eegdash) (0.11.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb->braindecode>=1.0->eegdash) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb->braindecode>=1.0->eegdash) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb->braindecode>=1.0->eegdash) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->skorch>=1.2.0->braindecode>=1.0->eegdash) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.0->wfdb->braindecode>=1.0->eegdash) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.0->braindecode>=1.0->eegdash) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mne>=1.10.0->braindecode>=1.0->eegdash) (3.0.3)
# Requirement already satisfied: hyper-connections>=0.1.8 in /usr/local/lib/python3.12/dist-packages (from local-attention->linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb->braindecode>=1.0->eegdash) (2.23)
# Downloading eegdash-0.4.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 3.6 MB/s eta 0:00:00
# Downloading eeglabio-0.1.2-py3-none-any.whl (10 kB)
# Downloading pymatreader-1.1.0-py3-none-any.whl (9.5 kB)
# Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.8 MB/s eta 0:00:00
# Downloading s3fs-2025.9.0-py3-none-any.whl (30 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 13.5 MB/s eta 0:00:00
# Downloading aiobotocore-2.25.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.4 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 25.7 MB/s eta 0:00:00
# Downloading xmltodict-1.0.2-py3-none-any.whl (13 kB)
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading botocore-1.40.61-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 109.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: xmltodict, wrapt, jmespath, fsspec, dnspython, aioitertools, pymongo, pymatreader, eeglabio, botocore, aiobotocore, s3fs, eegdash
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.0.0
#     Uninstalling wrapt-2.0.0:
#       Successfully uninstalled wrapt-2.0.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# Successfully installed aiobotocore-2.25.1 aioitertools-0.12.0 botocore-1.40.61 dnspython-2.8.0 eegdash-0.4.1 eeglabio-0.1.2 fsspec-2025.9.0 jmespath-1.0.1 pymatreader-1.1.0 pymongo-4.15.3 s3fs-2025.9.0 wrapt-1.17.3 xmltodict-1.0.2

# %%
from pathlib import Path
import math
import os
import random
from joblib import Parallel, delayed

import torch
from torch.utils.data import DataLoader
from torch import optim
from torch.nn.functional import l1_loss
from braindecode.preprocessing import create_fixed_length_windows
from braindecode.datasets.base import EEGWindowsDataset, BaseConcatDataset, BaseDataset
from braindecode.models import EEGNeX
from eegdash import EEGChallengeDataset

# %% [markdown]
# ⚠️ **In case of colab, before starting, make sure you're on a GPU instance for faster training!** ⚠️
#
# > If running on Google Colab, please request a GPU runtime by clicking `Runtime/Change runtime type` in the top bar menu, then selecting 'T4 GPU' under 'Hardware accelerator'.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
if device == "cuda":
    msg = "CUDA-enabled GPU found. Training should be faster."
else:
    msg = (
        "No GPU found. Training will be carried out on CPU, which might be "
        "slower.\n\nIf running on Google Colab, you can request a GPU runtime by"
        " clicking\n`Runtime/Change runtime type` in the top bar menu, then "
        "selecting 'T4 GPU'\nunder 'Hardware accelerator'."
    )
print(msg)
# Out:
# No GPU found. Training will be carried out on CPU, which might be slower.
#
# If running on Google Colab, you can request a GPU runtime by clicking
# `Runtime/Change runtime type` in the top bar menu, then selecting 'T4 GPU'
# under 'Hardware accelerator'.

# %% [markdown]
# ## 0. Understanding the externalizing factor regression task.
#
# The externalizing factor is a widely recognized construct in mental health research, representing a common underlying dimension of psychopathology across various disorders.
# Currently, the externalizing factor is often assessed using self-report questionnaires or clinician ratings, which can be subjective, prone to bias, and time-consuming.
# In the dataset of this challenge, the externalizing factor was assessed using the Child Behavior Checklist (CBCL) [McElroy et al., (2017)](https://doi.org/10.1111/jcpp.12849).
#
# The goal of Challenge 2 is to develop a model to predict the externalizing factor from EEG recordings.
# **The feasibility of using EEG data for this purpose is still an open question**.
# The solution may involve finding meaningful representations of the EEG data that correlate with the externalizing factor scores.
# The challenge encourages learning physiologically meaningful signal representations and discovery of reproducible biomarkers.
# If contestants are successful in this task, it could pave the way for more objective and efficient assessments of the externalizing factor in clinical settings.

# %% [markdown]
# ## 1. Loading the data
#
# ### A. Define local path and (down)load the data
#
# In this challenge 2 example, we load the EEG 2025 release using EEG Dash.
#
# > **Note:** in this example notebook, we load the contrast change detection task from one mini release only as an example. Naturally, you are encouraged to train your models on all complete releases, using data from all the tasks you deem relevant.

# %%
# The first step is to define the cache folder!
DATA_DIR = Path("~/mne_data/eeg2025_competition")

# Creating the path if it does not exist
DATA_DIR.mkdir(parents=True, exist_ok=True)

# We define the list of releases to load.
# Here, only release 5 is loaded.
release_list = ["R5"]

all_datasets_list = [
    EEGChallengeDataset(
        release=release,
        task="contrastChangeDetection",
        mini=True,
        description_fields=[
            "subject",
            "session",
            "run",
            "task",
            "age",
            "gender",
            "sex",
            "p_factor",
        ],
        cache_dir=DATA_DIR,
    )
    for release in release_list
]
print("Datasets loaded")
sub_rm = ["NDARWV769JM7", "NDARME789TD2", "NDARUA442ZVF", "NDARJP304NK1",
          "NDARTY128YLU", "NDARDW550GU6", "NDARLD243KRE", "NDARUJ292JXV", "NDARBA381JGH"]
# Out:
# ╭─────────────────────────────────────── EEG 2025 Competition Data Notice ────────────────────────────────────────╮
# │ This object loads the HBN dataset that has been preprocessed for the EEG Challenge:                             │
# │   * Downsampled from 500Hz to 100Hz                                                                             │
# │   * Bandpass filtered (0.5-50 Hz)                                                                               │
# │                                                                                                                 │
# │ For full preprocessing applied for competition details, see:                                                    │
# │   ]8;id=345651;https://github.com/eeg2025/downsample-datasets\https://github.com/eeg2025/downsample-datasets]8;;\                                                                │
# │                                                                                                                 │
# │ The HBN dataset have some preprocessing applied by the HBN team:                                                │
# │   * Re-reference (Cz Channel)                                                                                   │
# │                                                                                                                 │
# │ IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from ]8;id=994809;https://github.com/sccn/EEGDash/blob/develop/eegdash/api.py\EEGDashDataset]8;;\     │
# │ directly.                                                                                                       │
# │ If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the    │
# │ challenge data.                                                                                                 │
# ╰────────────────────────────────────────── Source: EEGChallengeDataset ──────────────────────────────────────────╯
# Datasets loaded

# %% [markdown]
# ### B. Combine the datasets into a single one
#
# Here, we combine the datasets from the different releases into a single
# ``BaseConcatDataset`` object.

# %%
all_datasets = BaseConcatDataset(all_datasets_list)
print(all_datasets.description)

raws = Parallel(n_jobs=os.cpu_count())(
    delayed(lambda d: d.raw)(d) for d in all_datasets.datasets
)
# Out:
#          subject  run                     task      age sex  p_factor  \
# 0   NDARAH793FBF    1  contrastChangeDetection   9.3427   M     0.317
# 1   NDARAH793FBF    2  contrastChangeDetection   9.3427   M     0.317
# 2   NDARAH793FBF    3  contrastChangeDetection   9.3427   M     0.317
# 3   NDARAJ689BVN    2  contrastChangeDetection   5.4878   F     0.084
# 4   NDARAJ689BVN    1  contrastChangeDetection   5.4878   F     0.084
# 5   NDARAJ689BVN    3  contrastChangeDetection   5.4878   F     0.084
# 6   NDARAP785CTE    3  contrastChangeDetection   8.7157   M    -0.960
# 7   NDARAP785CTE    1  contrastChangeDetection   8.7157   M    -0.960
# 8   NDARAP785CTE    2  contrastChangeDetection   8.7157   M    -0.960
# 9   NDARAU708TL8    1  contrastChangeDetection  12.0751   M     0.710
# 10  NDARAU708TL8    3  contrastChangeDetection  12.0751   M     0.710
# 11  NDARAU708TL8    2  contrastChangeDetection  12.0751   M     0.710
# 12  NDARBE091BGD    2  contrastChangeDetection   7.4098   M    -0.332
# 13  NDARBE091BGD    3  contrastChangeDetection   7.4098   M    -0.332
# 14  NDARBE091BGD    1  contrastChangeDetection   7.4098   M    -0.332
# 15  NDARBE103DHM    2  contrastChangeDetection  16.5657   M     0.109
# 16  NDARBE103DHM    3  contrastChangeDetection  16.5657   M     0.109
# 17  NDARBE103DHM    1  contrastChangeDetection  16.5657   M     0.109
# 18  NDARBF851NH6    2  contrastChangeDetection  18.8954   M       NaN
# 19  NDARBF851NH6    1  contrastChangeDetection  18.8954   M       NaN
# 20  NDARBF851NH6    3  contrastChangeDetection  18.8954   M       NaN
# 21  NDARBH228RDW    3  contrastChangeDetection   8.8285   F     1.679
# 22  NDARBH228RDW    1  contrastChangeDetection   8.8285   F     1.679
# 23  NDARBH228RDW    2  contrastChangeDetection   8.8285   F     1.679
# 24  NDARBJ674TVU    1  contrastChangeDetection   8.2262   M    -0.316
# 25  NDARBJ674TVU    2  contrastChangeDetection   8.2262   M    -0.316
# 26  NDARBJ674TVU    3  contrastChangeDetection   8.2262   M    -0.316
# 27  NDARBM433VER    2  contrastChangeDetection   9.5047   M     0.120
# 28  NDARBM433VER    3  contrastChangeDetection   9.5047   M     0.120
# 29  NDARBM433VER    1  contrastChangeDetection   9.5047   M     0.120
# 30  NDARCA740UC8    2  contrastChangeDetection  13.4198   M    -0.831
# 31  NDARCA740UC8    3  contrastChangeDetection  13.4198   M    -0.831
# 32  NDARCA740UC8    1  contrastChangeDetection  13.4198   M    -0.831
# 33  NDARCU633GCZ    3  contrastChangeDetection  17.7726   M     1.770
# 34  NDARCU633GCZ    1  contrastChangeDetection  17.7726   M     1.770
# 35  NDARCU633GCZ    2  contrastChangeDetection  17.7726   M     1.770
# 36  NDARCU736GZ1    2  contrastChangeDetection   8.2372   F    -1.071
# 37  NDARCU736GZ1    1  contrastChangeDetection   8.2372   F    -1.071
# 38  NDARCU736GZ1    3  contrastChangeDetection   8.2372   F    -1.071
# 39  NDARCU744XWL    1  contrastChangeDetection  10.5035   M     0.594
# 40  NDARCU744XWL    2  contrastChangeDetection  10.5035   M     0.594
# 41  NDARCU744XWL    3  contrastChangeDetection  10.5035   M     0.594
# 42  NDARDC843HHM    2  contrastChangeDetection   9.7593   M    -0.696
# 43  NDARDC843HHM    1  contrastChangeDetection   9.7593   M    -0.696
# 44  NDARDC843HHM    3  contrastChangeDetection   9.7593   M    -0.696
# 45  NDARDH086ZKK    1  contrastChangeDetection   9.4884   F    -0.729
# 46  NDARDH086ZKK    3  contrastChangeDetection   9.4884   F    -0.729
# 47  NDARDH086ZKK    2  contrastChangeDetection   9.4884   F    -0.729
# 48  NDARDL305BT8    2  contrastChangeDetection  15.1420   F     0.148
# 49  NDARDL305BT8    1  contrastChangeDetection  15.1420   F     0.148
# 50  NDARDL305BT8    3  contrastChangeDetection  15.1420   F     0.148
# 51  NDARDU853XZ6    1  contrastChangeDetection   8.5602   M     0.946
# 52  NDARDU853XZ6    3  contrastChangeDetection   8.5602   M     0.946
# 53  NDARDU853XZ6    2  contrastChangeDetection   8.5602   M     0.946
# 54  NDARDV245WJG    2  contrastChangeDetection   7.8725   M    -0.759
# 55  NDARDV245WJG    3  contrastChangeDetection   7.8725   M    -0.759
# 56  NDARDV245WJG    1  contrastChangeDetection   7.8725   M    -0.759
# 57  NDAREC480KFA    1  contrastChangeDetection  10.4762   M    -0.834
# 58  NDAREC480KFA    2  contrastChangeDetection  10.4762   M    -0.834
# 59  NDAREC480KFA    3  contrastChangeDetection  10.4762   M    -0.834
#
#    release_number  ehq_total commercial_use full_pheno  ...  thepresent  \
# 0              R5      60.03            Yes         No  ...   available
# 1              R5      60.03            Yes         No  ...   available
# 2              R5      60.03            Yes         No  ...   available
# 3              R5      46.69            Yes         No  ...   available
# 4              R5      46.69            Yes         No  ...   available
# 5              R5      46.69            Yes         No  ...   available
# 6              R5     100.05            Yes         No  ...   available
# 7              R5     100.05            Yes         No  ...   available
# 8              R5     100.05            Yes         No  ...   available
# 9              R5     100.05            Yes         No  ...   available
# 10             R5     100.05            Yes         No  ...   available
# 11             R5     100.05            Yes         No  ...   available
# 12             R5     -13.34            Yes        Yes  ...   available
# 13             R5     -13.34            Yes        Yes  ...   available
# 14             R5     -13.34            Yes        Yes  ...   available
# 15             R5      36.69            Yes         No  ...   available
# 16             R5      36.69            Yes         No  ...   available
# 17             R5      36.69            Yes         No  ...   available
# 18             R5      93.38            Yes         No  ...   available
# 19             R5      93.38            Yes         No  ...   available
# 20             R5      93.38            Yes         No  ...   available
# 21             R5     100.05            Yes         No  ...   available
# 22             R5     100.05            Yes         No  ...   available
# 23             R5     100.05            Yes         No  ...   available
# 24             R5      86.71            Yes        Yes  ...   available
# 25             R5      86.71            Yes        Yes  ...   available
# 26             R5      86.71            Yes        Yes  ...   available
# 27             R5      86.71            Yes         No  ...   available
# 28             R5      86.71            Yes         No  ...   available
# 29             R5      86.71            Yes         No  ...   available
# 30             R5      71.17            Yes         No  ...   available
# 31             R5      71.17            Yes         No  ...   available
# 32             R5      71.17            Yes         No  ...   available
# 33             R5      45.62            Yes        Yes  ...   available
# 34             R5      45.62            Yes        Yes  ...   available
# 35             R5      45.62            Yes        Yes  ...   available
# 36             R5      13.34            Yes         No  ...   available
# 37             R5      13.34            Yes         No  ...   available
# 38             R5      13.34            Yes         No  ...   available
# 39             R5      85.64            Yes         No  ...   available
# 40             R5      85.64            Yes         No  ...   available
# 41             R5      85.64            Yes         No  ...   available
# 42             R5     -40.02            Yes         No  ...   available
# 43             R5     -40.02            Yes         No  ...   available
# 44             R5     -40.02            Yes         No  ...   available
# 45             R5      90.05            Yes        Yes  ...   available
# 46             R5      90.05            Yes        Yes  ...   available
# 47             R5      90.05            Yes        Yes  ...   available
# 48             R5     100.05            Yes        Yes  ...   available
# 49             R5     100.05            Yes        Yes  ...   available
# 50             R5     100.05            Yes        Yes  ...   available
# 51             R5      96.72            Yes         No  ...   available
# 52             R5      96.72            Yes         No  ...   available
# 53             R5      96.72            Yes         No  ...   available
# 54             R5      53.36            Yes        Yes  ...   available
# 55             R5      53.36            Yes        Yes  ...   available
# 56             R5      53.36            Yes        Yes  ...   available
# 57             R5      -6.67            Yes        Yes  ...   available
# 58             R5      -6.67            Yes        Yes  ...   available
# 59             R5      -6.67            Yes        Yes  ...   available
#
#     diaryofawimpykid  contrastchangedetection_1 contrastchangedetection_2  \
# 0          available                  available                 available
# 1          available                  available                 available
# 2          available                  available                 available
# 3          available                  available                 available
# 4          available                  available                 available
# 5          available                  available                 available
# 6          available                  available                 available
# 7          available                  available                 available
# 8          available                  available                 available
# 9          available                  available                 available
# 10         available                  available                 available
# 11         available                  available                 available
# 12         available                  available                 available
# 13         available                  available                 available
# 14         available                  available                 available
# 15         available                  available                 available
# 16         available                  available                 available
# 17         available                  available                 available
# 18         available                  available                 available
# 19         available                  available                 available
# 20         available                  available                 available
# 21         available                  available                 available
# 22         available                  available                 available
# 23         available                  available                 available
# 24         available                  available                 available
# 25         available                  available                 available
# 26         available                  available                 available
# 27         available                  available                 available
# 28         available                  available                 available
# 29         available                  available                 available
# 30         available                  available                 available
# 31         available                  available                 available
# 32         available                  available                 available
# 33         available                  available                 available
# 34         available                  available                 available
# 35         available                  available                 available
# 36         available                  available                 available
# 37         available                  available                 available
# 38         available                  available                 available
# 39         available                  available                 available
# 40         available                  available                 available
# 41         available                  available                 available
# 42         available                  available                 available
# 43         available                  available                 available
# 44         available                  available                 available
# 45         available                  available                 available
# 46         available                  available                 available
# 47         available                  available                 available
# 48         available                  available                 available
# 49         available                  available                 available
# 50         available                  available                 available
# 51         available                  available                 available
# 52         available                  available                 available
# 53         available                  available                 available
# 54         available                  available                 available
# 55         available                  available                 available
# 56         available                  available                 available
# 57         available                  available                 available
# 58         available                  available                 available
# 59         available                  available                 available
#
#    contrastchangedetection_3 surroundsupp_1 surroundsupp_2 seqlearning6target  \
# 0                  available      available      available        unavailable
# 1                  available      available      available        unavailable
# 2                  available      available      available        unavailable
# 3                  available      available      available          available
# 4                  available      available      available          available
# 5                  available      available      available          available
# 6                  available      available      available        unavailable
# 7                  available      available      available        unavailable
# 8                  available      available      available        unavailable
# 9                  available      available      available        unavailable
# 10                 available      available      available        unavailable
# 11                 available      available      available        unavailable
# 12                 available      available      available          available
# 13                 available      available      available          available
# 14                 available      available      available          available
# 15                 available      available      available        unavailable
# 16                 available      available      available        unavailable
# 17                 available      available      available        unavailable
# 18                 available      available      available        unavailable
# 19                 available      available      available        unavailable
# 20                 available      available      available        unavailable
# 21                 available      available      available        unavailable
# 22                 available      available      available        unavailable
# 23                 available      available      available        unavailable
# 24                 available      available      available          available
# 25                 available      available      available          available
# 26                 available      available      available          available
# 27                 available      available      available        unavailable
# 28                 available      available      available        unavailable
# 29                 available      available      available        unavailable
# 30                 available      available      available        unavailable
# 31                 available      available      available        unavailable
# 32                 available      available      available        unavailable
# 33                 available      available      available        unavailable
# 34                 available      available      available        unavailable
# 35                 available      available      available        unavailable
# 36                 available      available      available          available
# 37                 available      available      available          available
# 38                 available      available      available          available
# 39                 available      available      available        unavailable
# 40                 available      available      available        unavailable
# 41                 available      available      available        unavailable
# 42                 available      available      available        unavailable
# 43                 available      available      available        unavailable
# 44                 available      available      available        unavailable
# 45                 available      available      available        unavailable
# 46                 available      available      available        unavailable
# 47                 available      available      available        unavailable
# 48                 available      available      available        unavailable
# 49                 available      available      available        unavailable
# 50                 available      available      available        unavailable
# 51                 available      available      available          available
# 52                 available      available      available          available
# 53                 available      available      available          available
# 54                 available      available      available          available
# 55                 available      available      available          available
# 56                 available      available      available          available
# 57                 available      available      available        unavailable
# 58                 available      available      available        unavailable
# 59                 available      available      available        unavailable
#
#    seqlearning8target symbolsearch
# 0           available    available
# 1           available    available
# 2           available    available
# 3         unavailable    available
# 4         unavailable    available
# 5         unavailable    available
# 6           available    available
# 7           available    available
# 8           available    available
# 9           available    available
# 10          available    available
# 11          available    available
# 12        unavailable    available
# 13        unavailable    available
# 14        unavailable    available
# 15          available    available
# 16          available    available
# 17          available    available
# 18          available    available
# 19          available    available
# 20          available    available
# 21          available    available
# 22          available    available
# 23          available    available
# 24        unavailable    available
# 25        unavailable    available
# 26        unavailable    available
# 27          available    available
# 28          available    available
# 29          available    available
# 30          available    available
# 31          available    available
# 32          available    available
# 33          available    available
# 34          available    available
# 35          available    available
# 36        unavailable    available
# 37        unavailable    available
# 38        unavailable    available
# 39          available    available
# 40          available    available
# 41          available    available
# 42          available    available
# 43          available    available
# 44          available    available
# 45          available    available
# 46          available    available
# 47          available    available
# 48          available    available
# 49          available    available
# 50          available    available
# 51        unavailable    available
# 52        unavailable    available
# 53        unavailable    available
# 54        unavailable    available
# 55        unavailable    available
# 56        unavailable    available
# 57          available    available
# 58          available    available
# 59          available    available
#
# [60 rows x 26 columns]

# %% [markdown]
# ### C. Inspect your data
#
# We can check what is inside the dataset consuming the
# MNE-object inside the Braindecode dataset.
#
# The following snippet, if uncommented, will show the first 10 seconds of the raw EEG signal.
# We can also inspect the data further by looking at the events and annotations.
# We strongly recommend you to take a look into the details and check how the events are structured.

# %%
raw = all_datasets.datasets[0].raw  # mne.io.Raw object
print(raw.info)

raw.plot(duration=10, scalings="auto", show=True)

print(raw.annotations)

SFREQ = 100
# Out:
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.3B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.5B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.0B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.4B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.7B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.7B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.49B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.63B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.9B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.2B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.7B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.7B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.93B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.57B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.27B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.66B/s]
# <Info | 9 non-empty values
#  bads: []
#  ch_names: E1, E2, E3, E4, E5, E6, E7, E8, E9, E10, E11, E12, E13, E14, ...
#  chs: 129 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  line_freq: 60.0
#  lowpass: 50.0 Hz
#  meas_date: 2025-08-19 00:06:17 UTC
#  nchan: 129
#  projs: []
#  sfreq: 100.0 Hz
#  subject_info: <subject_info | his_id: sub-NDARAH793FBF, sex: 1, birthday: 2016-04-15>
# >
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <Annotations | 75 segments: 9999 (1), break cnt (2), ...>

# %% [markdown]
# ## 2. Wrap the data into a PyTorch-compatible dataset
#
# The class below defines a dataset wrapper that will extract 2-second windows,
# uniformly sampled over the whole signal. In addition, it will add useful information
# about the extracted windows, such as the externalizing factor, the subject or the task.

# %%
class DatasetWrapper(BaseDataset):
    def __init__(
        self,
        dataset: EEGWindowsDataset,
        crop_size_samples: int,
        target_name: str = "externalizing",
        seed=None,
    ):
        self.dataset = dataset
        self.crop_size_samples = crop_size_samples
        self.target_name = target_name
        self.rng = random.Random(seed)

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, index):
        X, _, crop_inds = self.dataset[index]

        target = self.dataset.description[self.target_name]
        target = float(target)

        # Additional information:
        infos = {
            "subject": self.dataset.description["subject"],
            "sex": self.dataset.description["sex"],
            "age": float(self.dataset.description["age"]),
            "task": self.dataset.description["task"],
            "session": self.dataset.description.get("session", None) or "",
            "run": self.dataset.description.get("run", None) or "",
        }

        # Randomly crop the signal to the desired length:
        i_window_in_trial, i_start, i_stop = crop_inds
        assert i_stop - i_start >= self.crop_size_samples, f"{i_stop=} {i_start=}"
        start_offset = self.rng.randint(0, i_stop - i_start - self.crop_size_samples)
        i_start = i_start + start_offset
        i_stop = i_start + self.crop_size_samples
        X = X[:, start_offset : start_offset + self.crop_size_samples]

        return X, target, (i_window_in_trial, i_start, i_stop), infos

# %% [markdown]
# We filter out certain recordings, create fixed length windows and finally make use of our `DatasetWrapper`.

# %%
# Filter out recordings that are too short
all_datasets = BaseConcatDataset(
    [
        ds
        for ds in all_datasets.datasets
        if not ds.description.subject in sub_rm
        and ds.raw.n_times >= 4 * SFREQ
        and len(ds.raw.ch_names) == 129
        and not math.isnan(ds.description["p_factor"])
    ]
)

# Create 4-seconds windows with 2-seconds stride
windows_ds = create_fixed_length_windows(
    all_datasets,
    window_size_samples=4 * SFREQ,
    window_stride_samples=2 * SFREQ,
    drop_last_window=True,
)

# Wrap each sub-dataset in the windows_ds
windows_ds = BaseConcatDataset(
    [DatasetWrapper(ds, crop_size_samples=2 * SFREQ) for ds in windows_ds.datasets]
)
# Out:
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.6B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.1B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.7B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.3B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.2B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.5B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.36B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.57B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.74B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.7B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.9B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.44B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.14B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.0B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.2B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.78B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.0B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.2B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.3B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.39B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAH793FBF_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDARAH793FBF_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading sub-NDARAH793FBF_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAH793FBF_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.85B/s]
# Downloading sub-NDARAH793FBF_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.7B/s]
# Downloading sub-NDARAH793FBF_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAH793FBF_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.32B/s]
# Downloading sub-NDARAH793FBF_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.95B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.3B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.3B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.0B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.90B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.02B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.3B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.19B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.3B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.61B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.33B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.3B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.50B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.88B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.8B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.21B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.6B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.68B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.2B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.1B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.47B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.72B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.2B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.73B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.1B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.5B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.75B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.75B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.1B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.2B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAJ689BVN_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.3B/s]
# Downloading sub-NDARAJ689BVN_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.2B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.53B/s]
# Downloading sub-NDARAJ689BVN_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAJ689BVN_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAJ689BVN_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.6B/s]
# Downloading sub-NDARAJ689BVN_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.0B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.60B/s]
# Downloading sub-NDARAJ689BVN_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.58B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.40B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.9B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.87B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.3B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.0B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.0B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.0B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.5B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.1B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.2B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.53B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.3B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.3B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.8B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.1B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.23B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.9B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.6B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.43B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.28B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.93B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.1B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.42B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.14B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.2B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.0B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.49B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.63B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.9B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.1B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.65B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.8B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.6B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.42B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.62B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAP785CTE_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDARAP785CTE_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDARAP785CTE_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.4B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.5B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDARAP785CTE_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDARAP785CTE_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDARAP785CTE_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# ...
# Downloading sub-NDAREC480KFA_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.4B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.6B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.75B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.8B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.4B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.5B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.15B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.7B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.12B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.13B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 14.0B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.3B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.2B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.1B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.2B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.3B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.9B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.45B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.9B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.7B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.5B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.2B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.46B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.39B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.47B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.7B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.0B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.9B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.9B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.3B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.1B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.2B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.5B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.3B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.0B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.3B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.8B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.9B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.4B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 11.9B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.2B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.04B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.6B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.01B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 13.1B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.5B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.4B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 12.7B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.27B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.69B/s]

# %% [markdown]
# ## 3. Define, train and save a model
#
# Now we have our pytorch dataset necessary for the training!
#
# Below, we define a simple EEGNeX model from Braindecode.
# All the braindecode models expect the input to be of shape (batch_size, n_channels, n_times)
# and have a test coverage about the behavior of the model.
# However, you can use any pytorch model you want.

# %%
# Initialize model
model = EEGNeX(n_chans=129, n_outputs=1, n_times=2 * SFREQ).to(device)

# Specify optimizer
optimizer = optim.Adamax(params=model.parameters(), lr=0.002)

print(model)
# Out:
# ================================================================================================================================================================
# Layer (type (var_name):depth-idx)                            Input Shape               Output Shape              Param #                   Kernel Shape
# ================================================================================================================================================================
# EEGNeX (EEGNeX)                                              [1, 129, 200]             [1, 1]                    --                        --
# ├─Sequential (block_1): 1-1                                  [1, 129, 200]             [1, 8, 129, 200]          --                        --
# │    └─Rearrange (0): 2-1                                    [1, 129, 200]             [1, 1, 129, 200]          --                        --
# │    └─Conv2d (1): 2-2                                       [1, 1, 129, 200]          [1, 8, 129, 200]          512                       [1, 64]
# │    └─BatchNorm2d (2): 2-3                                  [1, 8, 129, 200]          [1, 8, 129, 200]          16                        --
# ├─Sequential (block_2): 1-2                                  [1, 8, 129, 200]          [1, 32, 129, 200]         --                        --
# │    └─Conv2d (0): 2-4                                       [1, 8, 129, 200]          [1, 32, 129, 200]         16,384                    [1, 64]
# │    └─BatchNorm2d (1): 2-5                                  [1, 32, 129, 200]         [1, 32, 129, 200]         64                        --
# ├─Sequential (block_3): 1-3                                  [1, 32, 129, 200]         [1, 64, 1, 50]            --                        --
# │    └─ParametrizedConv2dWithConstraint (0): 2-6             [1, 32, 129, 200]         [1, 64, 1, 200]           --                        [129, 1]
# │    │    └─ModuleDict (parametrizations): 3-1               --                        --                        8,256                     --
# │    └─BatchNorm2d (1): 2-7                                  [1, 64, 1, 200]           [1, 64, 1, 200]           128                       --
# │    └─ELU (2): 2-8                                          [1, 64, 1, 200]           [1, 64, 1, 200]           --                        --
# │    └─AvgPool2d (3): 2-9                                    [1, 64, 1, 200]           [1, 64, 1, 50]            --                        [1, 4]
# │    └─Dropout (4): 2-10                                     [1, 64, 1, 50]            [1, 64, 1, 50]            --                        --
# ├─Sequential (block_4): 1-4                                  [1, 64, 1, 50]            [1, 32, 1, 50]            --                        --
# │    └─Conv2d (0): 2-11                                      [1, 64, 1, 50]            [1, 32, 1, 50]            32,768                    [1, 16]
# │    └─BatchNorm2d (1): 2-12                                 [1, 32, 1, 50]            [1, 32, 1, 50]            64                        --
# ├─Sequential (block_5): 1-5                                  [1, 32, 1, 50]            [1, 48]                   --                        --
# │    └─Conv2d (0): 2-13                                      [1, 32, 1, 50]            [1, 8, 1, 50]             4,096                     [1, 16]
# │    └─BatchNorm2d (1): 2-14                                 [1, 8, 1, 50]             [1, 8, 1, 50]             16                        --
# │    └─ELU (2): 2-15                                         [1, 8, 1, 50]             [1, 8, 1, 50]             --                        --
# │    └─AvgPool2d (3): 2-16                                   [1, 8, 1, 50]             [1, 8, 1, 6]              --                        [1, 8]
# │    └─Dropout (4): 2-17                                     [1, 8, 1, 6]              [1, 8, 1, 6]              --                        --
# │    └─Flatten (5): 2-18                                     [1, 8, 1, 6]              [1, 48]                   --                        --
# ├─ParametrizedLinearWithConstraint (final_layer): 1-6        [1, 48]                   [1, 1]                    1                         --
# │    └─ModuleDict (parametrizations): 2-19                   --                        --                        --                        --
# │    │    └─ParametrizationList (weight): 3-2                --                        [1, 48]                   48                        --
# ================================================================================================================================================================
# Total params: 62,353
# Trainable params: 62,353
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 437.76
# ================================================================================================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 16.65
# Params size (MB): 0.22
# Estimated Total Size (MB): 16.97
# ================================================================================================================================================================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:543: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1027.)
#   return F.conv2d(

# %% [markdown]
# Finally, we can train our model. Here we define a simple training loop using pure PyTorch.
#
# > In this example, we only train for a single epoch. Feel free to increase the number of epochs.

# %%
# Create PyTorch Dataloader

num_workers = 1  # We are using a single worker, but you can increase this for faster data loading
dataloader = DataLoader(windows_ds, batch_size=128, shuffle=True, num_workers=num_workers)

n_epochs = 1

# Train model for 1 epoch
for epoch in range(n_epochs):

    for idx, batch in enumerate(dataloader):
        # Reset gradients
        optimizer.zero_grad()

        # Unpack the batch
        X, y, crop_inds, infos = batch
        X = X.to(dtype=torch.float32, device=device)
        y = y.to(dtype=torch.float32, device=device).unsqueeze(1)

        # Forward pass
        y_pred = model(X)

        # Compute loss
        loss = l1_loss(y_pred, y)
        print(f"Epoch {0} - step {idx}, loss: {loss.item()}")

        # Gradient backpropagation
        loss.backward()
        optimizer.step()

# Finally, we can save the model for later use
torch.save(model.state_dict(), "weights_challenge_2.pt")
print("Model saved as 'weights_challenge_2.pt'")
# Out:
# Epoch 0 - step 0, loss: 0.8147056102752686
# Epoch 0 - step 1, loss: 0.8273953199386597
# Epoch 0 - step 2, loss: 0.7059650421142578
# Epoch 0 - step 3, loss: 0.742368757724762
# Epoch 0 - step 4, loss: 0.8312780261039734
# Epoch 0 - step 5, loss: 0.7940396070480347
# Epoch 0 - step 6, loss: 0.772312343120575
# Epoch 0 - step 7, loss: 0.8310235738754272
# Epoch 0 - step 8, loss: 0.8639993667602539
# Epoch 0 - step 9, loss: 0.6848209500312805
# Epoch 0 - step 10, loss: 0.6790502071380615
# Epoch 0 - step 11, loss: 0.7953132390975952
# Epoch 0 - step 12, loss: 0.7328614592552185
# Epoch 0 - step 13, loss: 0.6969689726829529
# Epoch 0 - step 14, loss: 0.787416934967041
# Epoch 0 - step 15, loss: 0.700829029083252
# Epoch 0 - step 16, loss: 0.7895758152008057
# Epoch 0 - step 17, loss: 0.7046512961387634
# Epoch 0 - step 18, loss: 0.7830457091331482
# Epoch 0 - step 19, loss: 0.7017430067062378
# Epoch 0 - step 20, loss: 0.7122302055358887
# Epoch 0 - step 21, loss: 0.7966590523719788
# Epoch 0 - step 22, loss: 0.6991626620292664
# Epoch 0 - step 23, loss: 0.745099663734436
# Epoch 0 - step 24, loss: 0.8150256276130676
# Epoch 0 - step 25, loss: 0.7139524221420288
# Epoch 0 - step 26, loss: 0.7437987923622131
# Epoch 0 - step 27, loss: 0.726073682308197
# Epoch 0 - step 28, loss: 0.8013527989387512
# Epoch 0 - step 29, loss: 0.7481040954589844
# Epoch 0 - step 30, loss: 0.7025843262672424
# Epoch 0 - step 31, loss: 0.7406129240989685
# Epoch 0 - step 32, loss: 0.7101558446884155
# Epoch 0 - step 33, loss: 0.8067400455474854
# Epoch 0 - step 34, loss: 0.7555263638496399
# Epoch 0 - step 35, loss: 0.7441165447235107
# Epoch 0 - step 36, loss: 0.6482916474342346
# Epoch 0 - step 37, loss: 0.7609888911247253
# Epoch 0 - step 38, loss: 0.7959926724433899
# Epoch 0 - step 39, loss: 0.8496128916740417
# Epoch 0 - step 40, loss: 0.6758894920349121
# Epoch 0 - step 41, loss: 0.6509789824485779
# Epoch 0 - step 42, loss: 0.7948450446128845
# Epoch 0 - step 43, loss: 0.7308470606803894
# Epoch 0 - step 44, loss: 0.6729492545127869
# Epoch 0 - step 45, loss: 0.7433626651763916
# Epoch 0 - step 46, loss: 0.7616208791732788
# Epoch 0 - step 47, loss: 0.7106288075447083
# Epoch 0 - step 48, loss: 0.7591221928596497
# Epoch 0 - step 49, loss: 0.7392313480377197
# Epoch 0 - step 50, loss: 0.6901404857635498
# Epoch 0 - step 51, loss: 0.679002046585083
# Epoch 0 - step 52, loss: 0.7638814449310303
# Epoch 0 - step 53, loss: 0.7552947402000427
# Epoch 0 - step 54, loss: 0.7178871035575867
# Epoch 0 - step 55, loss: 0.7131693363189697
# Epoch 0 - step 56, loss: 0.791086733341217
# Epoch 0 - step 57, loss: 0.7672191858291626
# Epoch 0 - step 58, loss: 0.6313052177429199
# Epoch 0 - step 59, loss: 0.6840642094612122
# Epoch 0 - step 60, loss: 0.7552237510681152
# Epoch 0 - step 61, loss: 0.6513472199440002
# Epoch 0 - step 62, loss: 0.6788452863693237
# Epoch 0 - step 63, loss: 0.7519622445106506
# Epoch 0 - step 64, loss: 0.6853978633880615
# Model saved as 'weights_challenge_2.pt'
