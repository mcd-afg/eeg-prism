# %% [markdown]
# # Descargar los datos

# %% [markdown]
# Confirmo que pueda hacer uso de la GPU

# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import torch
print(f"GPUs disponibles: {torch.cuda.device_count()}")
print(f"Está disponible: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Nombre: {torch.cuda.get_device_name(0)}")
# Out:
# GPUs disponibles: 1
# Está disponible: True
# Nombre: NVIDIA RTX A5000

# %% [markdown]
# Imports

# %%
import os
import json
from pathlib import Path

import numpy as np
import pandas as pd
import mne
import torch

from braindecode.datasets.base import BaseDataset, BaseConcatDataset
from braindecode.preprocessing import create_fixed_length_windows
from braindecode.models import EEGNet
from braindecode.util import set_random_seeds
from braindecode import EEGClassifier
from braindecode.training import CroppedLoss

from skorch.helper import predefined_split
from skorch.callbacks import LRScheduler
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %% [markdown]
# Hacer la concatenación de la base de datos

# %%
data_path = Path("preprocessed_data")

mapping = {"bajo": 0, "medio": 1, "alto": 2}

datasets_list = []

for fif_path in data_path.glob("*_standardized_eeg.fif"):
    subj = fif_path.stem.split("_standardized_eeg")[0]
    raw = mne.io.read_raw_fif(fif_path, preload=False)

    with open(data_path / f"{subj}_description.json", "r") as f:
        desc = json.load(f)

    if isinstance(desc["p_factor_category"], str):
        desc["p_factor_category"] = mapping[desc["p_factor_category"]]
    
    # desc["target"] = desc["p_factor_category"]

    ds = BaseDataset(raw=raw, description=desc, target_name="p_factor_category")
    datasets_list.append(ds)

dataset = BaseConcatDataset(datasets_list)
print("Sujetos cargados:", len(dataset.datasets))
# Out:
# Opening raw data file preprocessed_data/NDARHT524ET0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRD943ZWU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39199 =      0.000 ...   391.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXV294YRJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38299 =      0.000 ...   382.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFT305CG1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41099 =      0.000 ...   410.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVG127VW5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXK254YD2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44599 =      0.000 ...   445.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREL164JM1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34899 =      0.000 ...   348.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXV034WE0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38599 =      0.000 ...   385.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRP801AX1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38199 =      0.000 ...   381.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBU098PJT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36099 =      0.000 ...   360.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMX328VWC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJF479TBL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNB773ECT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39399 =      0.000 ...   393.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBC865CXQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37699 =      0.000 ...   376.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKM476GFK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 46399 =      0.000 ...   463.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNK139XNA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31699 =      0.000 ...   316.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAW216PM7_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 45899 =      0.000 ...   458.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUK588UY6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 53399 =      0.000 ...   533.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHC661KGK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 87999 =      0.000 ...   879.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXY199VDP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 42499 =      0.000 ...   424.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFB506UJ3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 45599 =      0.000 ...   455.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAN229MTX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31799 =      0.000 ...   317.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFP813TL5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37099 =      0.000 ...   370.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMB458AWY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31999 =      0.000 ...   319.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZL113CU0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39999 =      0.000 ...   399.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUN221VCJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44299 =      0.000 ...   442.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBH502NZ9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHW575ZJ5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41299 =      0.000 ...   412.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXE542EMB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 46099 =      0.000 ...   460.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNX050XBN_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUE398GGV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 58399 =      0.000 ...   583.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPK095XX5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 45899 =      0.000 ...   458.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRP818DWL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36699 =      0.000 ...   366.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGY771DL8_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34399 =      0.000 ...   343.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWR112FNP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 48599 =      0.000 ...   485.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLC770YL9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 53499 =      0.000 ...   534.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXU902BRT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJR473HXT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34899 =      0.000 ...   348.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFD069AW7_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34899 =      0.000 ...   348.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKW511VE6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36299 =      0.000 ...   362.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCB504PGG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 61099 =      0.000 ...   610.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXP021FZ5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 20699 =      0.000 ...   206.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBP398JHL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34899 =      0.000 ...   348.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGU182ELW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLG154ZA3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTY010EYP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39999 =      0.000 ...   399.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPK300HMV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41699 =      0.000 ...   416.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWZ903DD2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUC629ZHX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 71299 =      0.000 ...   712.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNN989FZ4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 45699 =      0.000 ...   456.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJP146GT9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37799 =      0.000 ...   377.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYW514CH2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36899 =      0.000 ...   368.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKN175HWB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 46799 =      0.000 ...   467.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDD820LG7_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYL268BVG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39399 =      0.000 ...   393.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXV702MYC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRJ800YGA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAR305LXG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREH074NG8_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36499 =      0.000 ...   364.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCJ475WJP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUD894UP6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37199 =      0.000 ...   371.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAX287BLD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARND445LCA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36399 =      0.000 ...   363.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGY639ANB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUB100PP9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTW850GHU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMG675JB4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLA226ADX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36299 =      0.000 ...   362.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPG873DJP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREX065KJU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37299 =      0.000 ...   372.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLJ168LXY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35899 =      0.000 ...   358.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXG961UAB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJG581CCK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31999 =      0.000 ...   319.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPH176EWC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41699 =      0.000 ...   416.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKK392ZX2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37899 =      0.000 ...   378.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHG188YE9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36799 =      0.000 ...   367.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCH889NUF_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKM805EFA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRT994KAA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41599 =      0.000 ...   415.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARET671FTC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 43599 =      0.000 ...   435.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPB701XDP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 43799 =      0.000 ...   437.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBW268XPY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41699 =      0.000 ...   416.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREL721PGQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35999 =      0.000 ...   359.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTJ862ENU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36299 =      0.000 ...   362.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREA730YXX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 69199 =      0.000 ...   691.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVC140PKY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPL201YL4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZB323LHZ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37199 =      0.000 ...   371.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGR354WBH_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 51099 =      0.000 ...   510.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREK109WK1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 47099 =      0.000 ...   470.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZM362YA3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 106899 =      0.000 ...  1068.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFX455JFY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNU770PM5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35299 =      0.000 ...   352.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHC462NGR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38299 =      0.000 ...   382.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDX857DLB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 49699 =      0.000 ...   496.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUT651WFC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRG583CP3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37499 =      0.000 ...   374.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRY280KNW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 32099 =      0.000 ...   320.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFY009MNL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36399 =      0.000 ...   363.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRP163YRC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36299 =      0.000 ...   362.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCG159AAP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFC694PW2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39799 =      0.000 ...   397.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGN044FE4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 42699 =      0.000 ...   426.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUJ111XEZ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37599 =      0.000 ...   375.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDL129FV3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 43399 =      0.000 ...   433.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJJ389CP2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZN914GPB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMA629XDR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36099 =      0.000 ...   360.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYF338WW1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36999 =      0.000 ...   369.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYV571RJJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 33199 =      0.000 ...   331.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFK452XCU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 42999 =      0.000 ...   429.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBH701KA1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 19899 =      0.000 ...   198.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCE803VF5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34399 =      0.000 ...   343.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHM282EJ4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJV225EYT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37699 =      0.000 ...   376.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMH364EMW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHE896MYM_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBZ475NKK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWP458FH7_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGB040MGR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGD751MMW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37499 =      0.000 ...   374.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUN300FG1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35899 =      0.000 ...   358.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWF593BNF_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34399 =      0.000 ...   343.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNK768THB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 42199 =      0.000 ...   421.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJD704KEM_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVP520BAW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 18499 =      0.000 ...   184.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMR631KR5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41799 =      0.000 ...   417.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVC195NLH_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38999 =      0.000 ...   389.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHX252NVH_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAR991JAA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 32799 =      0.000 ...   327.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFA780CUG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35399 =      0.000 ...   353.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUF210FRD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 33499 =      0.000 ...   334.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZV895RZ5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPB984UTU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPR943MYP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 33899 =      0.000 ...   338.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVY366HWJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39099 =      0.000 ...   390.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAP283ZBW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWK212ZPX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 53499 =      0.000 ...   534.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVC558CAA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 48499 =      0.000 ...   484.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCV606ZZ5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34899 =      0.000 ...   348.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWJ498CZY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40599 =      0.000 ...   405.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLR586MPX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVN370YL8_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41099 =      0.000 ...   410.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRD326KB9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBD347AG0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36399 =      0.000 ...   363.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLW312JT8_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 43199 =      0.000 ...   431.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUJ744NEU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZK746XJ3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34399 =      0.000 ...   343.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLY947EXR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41199 =      0.000 ...   411.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBH024NH2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41399 =      0.000 ...   413.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVF884HMM_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31899 =      0.000 ...   318.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDG528KWJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREK801BPB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37699 =      0.000 ...   376.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKU278YRR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38399 =      0.000 ...   383.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKP823HEM_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDB033FW5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36299 =      0.000 ...   362.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAP176AD1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35999 =      0.000 ...   359.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUY379PT5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35699 =      0.000 ...   356.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKP414AZ5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44799 =      0.000 ...   447.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXB023AMW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMD134JRU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44099 =      0.000 ...   440.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUP249AMD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 47999 =      0.000 ...   479.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZH521MMD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35699 =      0.000 ...   356.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZB616FHG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31899 =      0.000 ...   318.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDJ970ELG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAF535XK6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35899 =      0.000 ...   358.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUJ894ZXG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37499 =      0.000 ...   374.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMM421CEC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35699 =      0.000 ...   356.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWX338NDL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMM594VJT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31799 =      0.000 ...   317.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPU329MDJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 91999 =      0.000 ...   919.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRV480PU1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCM050BN2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 53599 =      0.000 ...   535.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHX628PC6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36799 =      0.000 ...   367.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJR280FEJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36999 =      0.000 ...   369.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHX145ZKV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39799 =      0.000 ...   397.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCM953HKD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35399 =      0.000 ...   353.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAP785CTE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 54299 =      0.000 ...   542.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLK306VR9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41899 =      0.000 ...   418.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZC344VH2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWC905XUG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36799 =      0.000 ...   367.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZR968TLL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 49199 =      0.000 ...   491.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVV199XK2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35299 =      0.000 ...   352.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLZ986JLL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38699 =      0.000 ...   386.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWA433WYZ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37099 =      0.000 ...   370.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAY761BFH_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 75299 =      0.000 ...   752.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTH173DWQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44599 =      0.000 ...   445.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZW854BH0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 42299 =      0.000 ...   422.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREM500WWH_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40899 =      0.000 ...   408.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBF183RFB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJA830BYV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBM037ZM7_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREF074ZAQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 43199 =      0.000 ...   431.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLN550RM6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVP135ZGE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBL444FBA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39899 =      0.000 ...   398.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJG494YDY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCM214WFE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 49599 =      0.000 ...   495.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYM994YF0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXR965TFK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 49999 =      0.000 ...   499.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTU644WHZ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39899 =      0.000 ...   398.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBY041JPE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36099 =      0.000 ...   360.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGT634DUJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTG396FGE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36899 =      0.000 ...   368.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCT301RK9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 45999 =      0.000 ...   459.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLV090WM9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWC801CB5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44399 =      0.000 ...   443.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREY897LB1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 45799 =      0.000 ...   457.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWV452YZN_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKX788PHG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38299 =      0.000 ...   382.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRT854TMV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37699 =      0.000 ...   376.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWE898TG8_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 43399 =      0.000 ...   433.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHB764VZ2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMC481AWW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 64199 =      0.000 ...   641.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBU668NTV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUG126FUY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJT588ZAX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJN928UPY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40099 =      0.000 ...   400.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLJ728KPP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 42099 =      0.000 ...   420.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAD232HVV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 33999 =      0.000 ...   339.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCT889DMB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38199 =      0.000 ...   381.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARED628HMQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHN749RW4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36699 =      0.000 ...   366.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNV399BV4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38599 =      0.000 ...   385.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREC648WEL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34199 =      0.000 ...   341.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLW774VY1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDR898FMV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36399 =      0.000 ...   363.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJX258XF0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTJ032FJ2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35299 =      0.000 ...   352.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWF545PCM_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31799 =      0.000 ...   317.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHX963YU1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37699 =      0.000 ...   376.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHY693FNZ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 59299 =      0.000 ...   592.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRC175AK7_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 15399 =      0.000 ...   153.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWK605KC3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVF852TZ4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUZ062BWR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLYO38AJZ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 51699 =      0.000 ...   516.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZG044CJ5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 55999 =      0.000 ...   559.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYA877HN5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35699 =      0.000 ...   356.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDR067YMC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 43099 =      0.000 ...   430.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYA807PVN_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44299 =      0.000 ...   442.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARME100GK1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44599 =      0.000 ...   445.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGT623ZBY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 102999 =      0.000 ...  1029.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUX368CL6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFN636ZYB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37699 =      0.000 ...   376.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNV694EMG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKH168MC1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHF081GX4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 56699 =      0.000 ...   566.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZC445DDK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31899 =      0.000 ...   318.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGN205MUG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40999 =      0.000 ...   409.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDP815CNW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 64399 =      0.000 ...   643.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPU897CM5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVK407TGE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35299 =      0.000 ...   352.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCW071AU5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40799 =      0.000 ...   407.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKG460MWV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35999 =      0.000 ...   359.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAD269FZD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35399 =      0.000 ...   353.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYZ433UL5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 67299 =      0.000 ...   672.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUL077YNE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31699 =      0.000 ...   316.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYE221LZB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35299 =      0.000 ...   352.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGN680XJC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34899 =      0.000 ...   348.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYN333FPE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40399 =      0.000 ...   403.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCD075CMG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTK720LER_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38699 =      0.000 ...   386.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTN842FEV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34399 =      0.000 ...   343.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVJ468UZC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39499 =      0.000 ...   394.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHR468PPJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 32499 =      0.000 ...   324.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPF395NV5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36799 =      0.000 ...   367.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJC559WW5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFM006EM0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39699 =      0.000 ...   396.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXY162ERA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXF294ME0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39999 =      0.000 ...   399.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZU615HUG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37499 =      0.000 ...   374.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBW660FLT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 79899 =      0.000 ...   798.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYA952GA1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39599 =      0.000 ...   395.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNY023FWG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 51799 =      0.000 ...   517.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDJ204EPU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39099 =      0.000 ...   390.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPD855ARC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36099 =      0.000 ...   360.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGV263ZRY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36899 =      0.000 ...   368.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRC295CHW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37599 =      0.000 ...   375.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGX760NYV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJY757LJU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31899 =      0.000 ...   318.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFA358RJJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREV617HAP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMC694YF3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36699 =      0.000 ...   366.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPW915RGD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVY054WEA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZM903TNL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35699 =      0.000 ...   356.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTF150VPJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHE772FWW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38199 =      0.000 ...   381.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLD978JVJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDR103FJQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 43899 =      0.000 ...   438.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRH407MEY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37899 =      0.000 ...   378.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYH951HH5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREK549XUQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRM741RJ0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVD599VP2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44599 =      0.000 ...   445.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVK922KE5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREB303XDC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPV595RWB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZF615DC0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36699 =      0.000 ...   366.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZG861CXJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLR924YAV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37199 =      0.000 ...   371.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNA335GX2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 42299 =      0.000 ...   422.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTB213ML4_standardized_eeg.fif...
# Isotrak not found
# ...
# Ready.
# Opening raw data file preprocessed_data/NDARXF203DCD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41099 =      0.000 ...   410.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDK794WV3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35899 =      0.000 ...   358.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNN164EA6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMZ119VPH_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41999 =      0.000 ...   419.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMV575DC1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36199 =      0.000 ...   361.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXR250LW3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMR306ZKG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36499 =      0.000 ...   364.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHR099EWX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPK223WVZ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41599 =      0.000 ...   415.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZW662UK6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38899 =      0.000 ...   388.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVA602LMV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARPA005VVK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJA157YB3_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 31899 =      0.000 ...   318.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAT680GJA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 46399 =      0.000 ...   463.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZL799MFW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41399 =      0.000 ...   413.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRX552PP2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36699 =      0.000 ...   366.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTH261GB5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJH707GJM_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37299 =      0.000 ...   372.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXU975RAJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 32299 =      0.000 ...   322.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFU395UBW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35999 =      0.000 ...   359.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWT715BMK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAH239PGG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36099 =      0.000 ...   360.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCA153NKE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNC130ZLK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWV794VM2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38599 =      0.000 ...   385.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJL292RYV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35999 =      0.000 ...   359.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLY867ZD4_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39899 =      0.000 ...   398.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGK253TTG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 65999 =      0.000 ...   659.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDZ425JVB_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 45699 =      0.000 ...   456.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUF170ABA_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMH305FWL_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36799 =      0.000 ...   367.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZZ741VJE_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35399 =      0.000 ...   353.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYE155BLQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36299 =      0.000 ...   362.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNG968RB9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41199 =      0.000 ...   411.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARGC407NV7_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35999 =      0.000 ...   359.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTU777GVV_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40099 =      0.000 ...   400.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYU575CE2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLP413TUX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 37199 =      0.000 ...   371.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREX589EXG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVV704MND_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTL667CCG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREP458FBK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35399 =      0.000 ...   353.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUF152ARR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTL878RZ2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40299 =      0.000 ...   402.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDU482DGK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38099 =      0.000 ...   380.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRH199NCH_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 12199 =      0.000 ...   121.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTZ571MJQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUC144FN6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36999 =      0.000 ...   369.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKF442GZ5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 46399 =      0.000 ...   463.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKM605AXX_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34899 =      0.000 ...   348.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFJ488VPT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMD638CM6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 68099 =      0.000 ...   680.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARVH565FX9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREV527ZRF_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39199 =      0.000 ...   391.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXG646PM9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXR123PFR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFN221WW5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARKJ238NTJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 32399 =      0.000 ...   323.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREZ416XDW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35499 =      0.000 ...   354.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTT476DAT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNY875DR2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 39699 =      0.000 ...   396.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARXY567ZML_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36299 =      0.000 ...   362.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUX885LMW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYK713TGJ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36899 =      0.000 ...   368.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWC399JLD_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTH930FNK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38199 =      0.000 ...   381.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDW178AC6_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTT667RKQ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUK658FMU_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 42299 =      0.000 ...   422.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARFW002KMK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35399 =      0.000 ...   353.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUL675RXW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDE355JYM_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 53999 =      0.000 ...   539.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDAREE675XRY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40799 =      0.000 ...   407.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTE424BUF_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35399 =      0.000 ...   353.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHM611GDR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDH214UVC_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35599 =      0.000 ...   355.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARJD142DHR_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 65799 =      0.000 ...   657.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYG331FLY_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 45299 =      0.000 ...   452.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRK882CLT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34699 =      0.000 ...   346.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARUP441BKK_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 69399 =      0.000 ...   693.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARTK933KL9_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMJ333WJM_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38399 =      0.000 ...   383.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARAH948UF0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNC489BX5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 38199 =      0.000 ...   381.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRY097FUT_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36299 =      0.000 ...   362.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRE214UKF_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 44399 =      0.000 ...   443.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCJ011TTG_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35199 =      0.000 ...   351.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARND805ZTP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 65999 =      0.000 ...   659.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARDR439HY2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35799 =      0.000 ...   357.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWT086XMF_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 36799 =      0.000 ...   367.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARCH001CN2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34799 =      0.000 ...   347.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARBX479JVN_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 58599 =      0.000 ...   585.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARNA856AY1_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 97999 =      0.000 ...   979.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHC426PAW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35099 =      0.000 ...   350.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARMR570GJ5_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 40099 =      0.000 ...   400.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARWH725TXP_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34999 =      0.000 ...   349.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARYY218LU2_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 100699 =      0.000 ...  1006.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARRF011FG0_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 35899 =      0.000 ...   358.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARLY585ZVN_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34599 =      0.000 ...   345.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARHP924ZHW_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 34499 =      0.000 ...   344.990 secs
# Ready.
# Opening raw data file preprocessed_data/NDARZV421TCZ_standardized_eeg.fif...
# Isotrak not found
#     Range : 0 ... 41899 =      0.000 ...   418.990 secs
# Ready.
# Sujetos cargados: 2643

# %% [markdown]
# Voy a quitar los sujetos con menos de 8 segundos de datos

# %%
SFREQ = 100

# %%
#Creo el nuevo dataset
dataset = BaseConcatDataset(
    [
        ds for ds in dataset.datasets
        if ds.raw.n_times >= 4 * SFREQ
    ]
)

# %% [markdown]
# Modelo

# %%
n_times = 400
import torch

from braindecode.models import EEGNet
from braindecode.util import set_random_seeds

cuda = torch.cuda.is_available()  # check if GPU is available, if True chooses to use it
device = "cuda" if cuda else "cpu"
if cuda:
    torch.backends.cudnn.benchmark = True
# Set random seed to be able to roughly reproduce results
# Note that with cudnn benchmark set to True, GPU indeterminism
# may still make results substantially different between runs.
# To obtain more consistent results at the cost of increased computation time,
# you can set `cudnn_benchmark=False` in `set_random_seeds`
# or remove `torch.backends.cudnn.benchmark = True`
seed = 20200220
set_random_seeds(seed=seed, cuda=cuda)

n_classes = 3
classes = list(range(n_classes))
# Extract number of chans from dataset
n_chans = dataset[0][0].shape[0]

model = EEGNet(
    n_chans,
    n_classes,
    n_times=n_times,
    final_conv_length="auto",
)

# # Display torchinfo table describing the model
# print(model)

# Send model to GPU
if cuda:
    _ = model.cuda()
# Out:
# /home/jhoham-oliveros/.venv/lib/python3.11/site-packages/braindecode/util.py:52: UserWarning: torch.backends.cudnn.benchmark was set to True which may results in lack of reproducibility. In some cases to ensure reproducibility you may need to set torch.backends.cudnn.benchmark to False.
#   warn(

# %%
#Paso a predicciones de cropped
model.to_dense_prediction_model()

# %%
#Miro el stride
n_preds_per_input = model.get_output_shape()[2]
n_preds_per_input
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.venv/lib/python3.11/site-packages/braindecode/models/base.py:180, in EEGModuleMixin.get_output_shape(self)
#     178 try:
#     179     return tuple(
# --> 180         self.forward(  # type: ignore
#     181             torch.zeros(
#     182                 self.input_shape,
#     183                 dtype=next(self.parameters()).dtype,  # type: ignore
#     184                 device=next(self.parameters()).device,  # type: ignore
#     185             )
#     186         ).shape
#     187     )
#     188 except RuntimeError as exc:
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# RuntimeError: Calculated padded input size per channel: (1 x 347). Kernel size: (1 x 353). Kernel size can't be greater than actual input size
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 #Miro el stride
# ----> 2 n_preds_per_input = model.get_output_shape()[2]
#       3 n_preds_per_input
#
# File ~/.venv/lib/python3.11/site-packages/braindecode/models/base.py:202, in EEGModuleMixin.get_output_shape(self)
#     189 if str(exc).endswith(
#     190     (
#     191         "Output size is too small",
#     192         "Kernel size can't be greater than actual input size",
#     193     )
#     194 ):
#     195     msg = (
#     196         "During model prediction RuntimeError was thrown showing that at some "
#     197         f"layer `{str(exc).split('.')[-1]}` (see above in the stacktrace). This "
#    (...)    200         f"{self.input_shape}."
#     201     )
# --> 202     raise ValueError(msg) from exc
#     203 raise exc
#
# ValueError: During model prediction RuntimeError was thrown showing that at some layer ` Kernel size can't be greater than actual input size` (see above in the stacktrace). This could be caused by providing too small `n_times`/`input_window_seconds`. Model may require longer chunks of signal in the input than (1, 128, 400).

# %% [markdown]
# Creo las ventanas

# %%
SFREQ = 100
windows_dataset = create_fixed_length_windows(
    dataset,
    window_size_samples=n_times,
    window_stride_samples=250,
    drop_last_window=False,
    preload=False,
)

# %% [markdown]
# Hago el split del dataset en train y validación

# %%
description = windows_dataset.description
labels = description["p_factor_category"].to_list()

from sklearn.model_selection import train_test_split

train_idx, valid_idx = train_test_split(
    np.arange(len(windows_dataset.datasets)),
    test_size=0.2,
    stratify=labels,
    random_state=42
)

splitted = {
    "train": BaseConcatDataset([windows_dataset.datasets[i] for i in train_idx]),
    "valid": BaseConcatDataset([windows_dataset.datasets[i] for i in valid_idx]),
}

train_set = splitted["train"]
valid_set = splitted["valid"]

# %%
from skorch.callbacks import LRScheduler, PrintLog
from skorch.helper import predefined_split

from braindecode import EEGClassifier
from braindecode.training import CroppedLoss

# These values we found good for shallow network:
lr = 0.0625 * 0.01
weight_decay = 0

# For deep4 they should be:
# lr = 1 * 0.01
# weight_decay = 0.5 * 0.001

batch_size = 32
n_epochs = 2

clf = EEGClassifier(
    model,
    cropped=True,
    criterion=CroppedLoss,
    criterion__loss_function=torch.nn.functional.cross_entropy,
    optimizer=torch.optim.AdamW,
    train_split=predefined_split(valid_set),
    optimizer__lr=lr,
    optimizer__weight_decay=weight_decay,
    iterator_train__shuffle=True,
    batch_size=batch_size,
    callbacks=[
        "accuracy",
        ("lr_scheduler", LRScheduler("CosineAnnealingLR", T_max=n_epochs - 1)),
        PrintLog()
    ],
    device=device,
    classes=classes,
)

torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.benchmark = False  # reduce picos de memoria
torch.backends.cudnn.enabled = True
# Model training for a specified number of epochs. ``y`` is None as it is already supplied
# in the dataset.
_ = clf.fit(train_set, y=None, epochs=n_epochs)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Prueba que esté tomando bien el target

# %%
print(type(windows_dataset))
print(len(windows_dataset))
print(windows_dataset[0][0].shape)  # primera ventana, datos
print(windows_dataset[0][1])        # primera ventana, target
# Out:
# <class 'braindecode.datasets.base.BaseConcatDataset'>
# 147390
# (128, 1000)
# -1

# %%
#Vpy a guardar los valores que está tomando como target yw
all_targets = []

for i in range(len(windows_dataset)):
    _, y, _ = windows_dataset[i]
    all_targets.append(int(y))  # convertir a int por seguridad

print(len(all_targets))
print(set(all_targets))  # valores únicos
# Out:
# 147390
# {-1}

# %%
print(windows_dataset.description["target"].unique())
print(windows_dataset.description["target"].dtype)
# Out:
# [1 2 0]
# int64

# %%
print(windows_dataset.datasets[0].description)
# Out:
# subject                      NDARHT524ET0
# task                         RestingState
# age                                6.5013
# sex                                     M
# p_factor                             0.46
# release_number                         R9
# ehq_total                           51.14
# commercial_use                        Yes
# full_pheno                            Yes
# attention                           1.361
# internalizing                      -0.194
# externalizing                      -0.731
# restingstate                    available
# despicableme                    available
# funwithfractals                 available
# thepresent                      available
# diaryofawimpykid                available
# contrastchangedetection_1       available
# contrastchangedetection_2       available
# contrastchangedetection_3       available
# surroundsupp_1                  available
# surroundsupp_2                  available
# seqlearning6target              available
# seqlearning8target            unavailable
# symbolsearch                    available
# p_factor_category                       1
# target                                  1
# dtype: object

# %%
n_preds_per_input
# Out:
# 19

# %% [markdown]
# # Código viejo

# %% [markdown]
# Crear las ventanas

# %%
SFREQ = 100
window_size_samples = 4 * SFREQ   # 16s
window_stride_samples = 2 * SFREQ # 8s

windows_dataset = create_fixed_length_windows(
    dataset,
    window_size_samples=window_size_samples,
    window_stride_samples=window_stride_samples,
    drop_last_window=False,
    preload=True,
)

# %% [markdown]
# Hago el split solo train-val

# %%
description = windows_dataset.description
labels = description["p_factor_category"].to_list()

from sklearn.model_selection import train_test_split

train_idx, valid_idx = train_test_split(
    np.arange(len(windows_dataset.datasets)),
    test_size=0.2,
    stratify=labels,
    random_state=42
)

splitted = {
    "train": BaseConcatDataset([windows_dataset.datasets[i] for i in train_idx]),
    "valid": BaseConcatDataset([windows_dataset.datasets[i] for i in valid_idx]),
}

train_set = splitted["train"]
valid_set = splitted["valid"]

# %% [markdown]
# Creo el modelo y lo paso a predicción densa

# %%
cuda = torch.cuda.is_available()
device = "cuda" if cuda else "cpu"

set_random_seeds(seed=42, cuda=cuda)

n_chans = 128
n_classes = 3
n_times = window_size_samples  # 4s

model = EEGNet(
    n_chans=n_chans,
    n_outputs=n_classes,
    n_times=n_times
)

if cuda:
    model.cuda()

model.to_dense_prediction_model()
n_preds_per_input = model.get_output_shape()[2]

print("Predictions por input:", n_preds_per_input)
# Out:
# /home/jhoham-oliveros/.venv/lib/python3.11/site-packages/braindecode/util.py:52: UserWarning: torch.backends.cudnn.benchmark was set to True which may results in lack of reproducibility. In some cases to ensure reproducibility you may need to set torch.backends.cudnn.benchmark to False.
#   warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.venv/lib/python3.11/site-packages/braindecode/models/base.py:180, in EEGModuleMixin.get_output_shape(self)
#     178 try:
#     179     return tuple(
# --> 180         self.forward(  # type: ignore
#     181             torch.zeros(
#     182                 self.input_shape,
#     183                 dtype=next(self.parameters()).dtype,  # type: ignore
#     184                 device=next(self.parameters()).device,  # type: ignore
#     185             )
#     186         ).shape
#     187     )
#     188 except RuntimeError as exc:
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# RuntimeError: Calculated padded input size per channel: (1 x 3947). Kernel size: (1 x 3969). Kernel size can't be greater than actual input size
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 20
#      17     model.cuda()
#      19 model.to_dense_prediction_model()
# ---> 20 n_preds_per_input = model.get_output_shape()[2]
#      22 print("Predictions por input:", n_preds_per_input)
#
# File ~/.venv/lib/python3.11/site-packages/braindecode/models/base.py:202, in EEGModuleMixin.get_output_shape(self)
#     189 if str(exc).endswith(
#     190     (
#     191         "Output size is too small",
#     192         "Kernel size can't be greater than actual input size",
#     193     )
#     194 ):
#     195     msg = (
#     196         "During model prediction RuntimeError was thrown showing that at some "
#     197         f"layer `{str(exc).split('.')[-1]}` (see above in the stacktrace). This "
#    (...)    200         f"{self.input_shape}."
#     201     )
# --> 202     raise ValueError(msg) from exc
#     203 raise exc
#
# ValueError: During model prediction RuntimeError was thrown showing that at some layer ` Kernel size can't be greater than actual input size` (see above in the stacktrace). This could be caused by providing too small `n_times`/`input_window_seconds`. Model may require longer chunks of signal in the input than (1, 128, 4000).

# %%
item = train_set.datasets[0][0]
print(type(item))
print(len(item))
print(item)
# Out:
# <class 'tuple'>
# 3
# (array([[ 4.50527878e-05,  1.44036067e-05,  2.90817989e-05, ...,
#         -1.18494308e-05, -2.10916169e-05, -2.50878948e-05],
#        [ 8.06073003e-05,  2.47137177e-06,  1.36701274e-05, ...,
#         -1.48206955e-05, -1.72209966e-05, -1.44601863e-05],
#        [ 7.88024117e-05,  3.02632998e-06,  1.07903716e-05, ...,
#         -4.90740877e-06, -9.68882705e-06, -1.26947170e-05],
#        ...,
#        [ 9.08524016e-05,  3.54386029e-05,  7.69710095e-05, ...,
#          3.82810940e-05,  2.99909352e-05,  2.93819248e-05],
#        [ 5.07642726e-05,  1.49874231e-05,  3.18266466e-05, ...,
#         -4.01048979e-04, -3.97911441e-04, -3.88309301e-04],
#        [ 4.28216772e-05,  4.11674591e-06,  1.63652112e-05, ...,
#         -1.74224100e-04, -1.71812702e-04, -1.63363104e-04]],
#       shape=(128, 4000), dtype=float32), -1, [0, 0, 4000])

# %% [markdown]
# # Código para probar cuánta GPU usar

# %%
import torch
import math

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- Ajusta según tu caso ---
n_chans = 128
n_samples = 200   # microventana de 2s a 100 Hz
n_outputs = 3     # p-factor categórico
dtype = torch.float32

# --- Define o importa tu modelo aquí ---
# Ejemplo: model = SyncNet(n_chans=n_chans, n_outputs=n_outputs, input_window_samples=n_samples).to(device)
# Reemplaza por el modelo que usarás.
model = model.to(device)  # asume que ya tienes model creado

# --- Función que prueba un batch y devuelve peak memory en MB ---
def test_batch_memory(batch_size):
    try:
        torch.cuda.empty_cache()
        torch.cuda.reset_peak_memory_stats(device)
        X = torch.randn(batch_size, n_chans, n_samples, dtype=dtype, device=device)
        y = torch.randint(0, n_outputs, (batch_size,), device=device)

        model.train()
        optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)  # solo para backward
        optimizer.zero_grad()
        out = model(X)
        loss = torch.nn.functional.cross_entropy(out, y)
        loss.backward()
        optimizer.step()

        peak_mb = torch.cuda.max_memory_allocated(device) / (1024**2)
        return True, peak_mb
    except RuntimeError as e:
        # Captura OOM
        if 'out of memory' in str(e).lower():
            torch.cuda.empty_cache()
            return False, None
        else:
            raise

# --- Búsqueda binaria para batch máximo seguro ---
def find_max_batch(min_b=1, max_b=2048, safety_margin=0.85):
    # Primero prueba max_b por si ya cabe
    lo, hi = min_b, max_b
    last_ok = min_b
    while lo <= hi:
        mid = (lo + hi) // 2
        ok, peak = test_batch_memory(mid)
        print(f"Testing batch={mid} -> ok={ok}, peak={peak}")
        if ok:
            last_ok = mid
            lo = mid + 1
        else:
            hi = mid - 1
    # Ahora medir el último_ok para saber el peak y aplicar safety margin
    ok, peak = test_batch_memory(last_ok)
    if not ok:
        return last_ok, None
    max_safe = int(last_ok * safety_margin)
    return last_ok, max_safe, peak

# --- Uso ejemplo ---
# Ojo: find_max_batch hará múltiples forward/backward (puede tardar un poco)
last_ok, max_safe, peak = find_max_batch(min_b=8, max_b=1024, safety_margin=0.8)
print("Último batch que cabe:", last_ok)
print("Batch 'seguro' sugerido (con margen):", max_safe)
print("Peak MB del último ok:", peak)
# Out:
# Testing batch=516 -> ok=True, peak=2280.416015625
# Testing batch=770 -> ok=True, peak=3402.59765625
# Testing batch=897 -> ok=True, peak=3962.60400390625
# Testing batch=961 -> ok=True, peak=4245.05078125
# Testing batch=993 -> ok=True, peak=4387.00146484375
# Testing batch=1009 -> ok=True, peak=4456.9208984375
# Testing batch=1017 -> ok=True, peak=4492.94140625
# Testing batch=1021 -> ok=True, peak=4510.57470703125
# Testing batch=1023 -> ok=True, peak=4520.02880859375
# Testing batch=1024 -> ok=True, peak=4524.02880859375
# Último batch que cabe: 1024
# Batch 'seguro' sugerido (con margen): 819
# Peak MB del último ok: 2524.62646484375
